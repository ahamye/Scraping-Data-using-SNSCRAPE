# %% [markdown]
# **Extraxt the tweets using the SNS Scraper**

# %%
# !pip3 install snscrape

# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter

# %%
scraper=sntwitter.TwitterSearchScraper("اليمن OR الحوثي OR التحالف OR صنعاء OR عدن OR مأرب OR المحويت OR المجلس_الانتقالي_الجنوبي OR صعدة")
tweets=[]
n_tweets=500
for i,tweet in tqdm(enumerate(scraper.get_items()),total=n_tweets):
    
    data=[
        tweet.date,
        tweet.id,
        tweet.content,
        tweet.user.username,
        tweet.likeCount,
        tweet.retweetCount,
        tweet.lang,
        tweet.sourceLabel,
        tweet.renderedContent,
        tweet.coordinates,
        tweet.place,
        tweet.hashtags
    ]
    
    tweets.append(data)
    if i>n_tweets:
        break
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# <ipython-input-3-30f16a68ea88>:9: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,

# %%
tweets

# %%
tweet_df = pd.DataFrame(
    tweets, columns=["date","id","tweet","username","like_count","retweet_count","lang","source","renderedContent","coordinates",
                    "place","hashtags"]
)

# %%
tweet_df
# Out:
#                          date                   id  \
# 0   2023-04-10 12:43:39+00:00  1645407191141175297
# 1   2023-04-10 12:43:37+00:00  1645407183629324291
# 2   2023-04-10 12:43:36+00:00  1645407181754310656
# 3   2023-04-10 12:43:11+00:00  1645407075369984001
# 4   2023-04-10 12:43:11+00:00  1645407074392702976
# ..                        ...                  ...
# 497 2023-04-10 12:09:09+00:00  1645398511012249601
# 498 2023-04-10 12:09:07+00:00  1645398503747727361
# 499 2023-04-10 12:09:06+00:00  1645398496168534017
# 500 2023-04-10 12:09:05+00:00  1645398494490812416
# 501 2023-04-10 12:09:04+00:00  1645398490707640321
#
#                                                  tweet         username  \
# 0                                  @aljabri_ebrahim 👍🏻       alymn_zynb
# 1    @HatemAlfageh الحوثيون اذهلوا العالم بقوتهم وص...   AbbasShehab123
# 2    اليمن الأولى.. ريمة.\nكلما سمعت جهلا شماليا مت...       Nalsoufi16
# 3    @aaaa_1dd هاهم يرون ثمار تضحياتهم جعلوا العالم...  A38606504Sameer
# 4    @Waad_Al_shaikh @Salehjoraibi أنت انسان أهبل م...  qZK2iEpMXrs77rc
# ..                                                 ...              ...
# 497  @alshafafehri @rajhiabdlmohsen هذي اقدر اسويها...  AbdullahMohsaen
# 498  @amer_thabet2021 هاذا  تعلم على يدكم الدجل وسب...     kdrhosyn0508
# 499  @YaserAlyamani ههههههه مسكين ياسر اليماني يحلم...     nymr71845703
# 500  #السبق_اليمني: المركز الوطني للأرصاد يتوقع غبا...  Alsabq_alyemeni
# 501  من وجهتي سياسية الحرب الاقتصادية هزمت سياسة ال...     ukarabic2021
#
#      like_count  retweet_count lang               source  \
# 0             0              0  qme  Twitter for Android
# 1             0              0   ar   Twitter for iPhone
# 2             0              0   ar      Twitter Web App
# 3             0              0   ar   Twitter for iPhone
# 4             0              0   ar  Twitter for Android
# ..          ...            ...  ...                  ...
# 497           0              0   ar   Twitter for iPhone
# 498           0              0   ar  Twitter for Android
# 499           0              0   ar  Twitter for Android
# 500           0              0   ar   Twitter for iPhone
# 501           0              0   ar   Twitter for iPhone
#
#                                        renderedContent coordinates place  \
# 0                                  @aljabri_ebrahim 👍🏻        None  None
# 1    @HatemAlfageh الحوثيون اذهلوا العالم بقوتهم وص...        None  None
# 2    اليمن الأولى.. ريمة.\nكلما سمعت جهلا شماليا مت...        None  None
# 3    @aaaa_1dd هاهم يرون ثمار تضحياتهم جعلوا العالم...        None  None
# 4    @Waad_Al_shaikh @Salehjoraibi أنت انسان أهبل م...        None  None
# ..                                                 ...         ...   ...
# 497  @alshafafehri @rajhiabdlmohsen هذي اقدر اسويها...        None  None
# 498  @amer_thabet2021 هاذا  تعلم على يدكم الدجل وسب...        None  None
# 499  @YaserAlyamani ههههههه مسكين ياسر اليماني يحلم...        None  None
# 500  #السبق_اليمني: المركز الوطني للأرصاد يتوقع غبا...        None  None
# 501  من وجهتي سياسية الحرب الاقتصادية هزمت سياسة ال...        None  None
#
#                                      hashtags
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ..                                        ...
# 497                                      None
# 498                                      None
# 499                                      None
# 500  [السبق_اليمني, مأرب, شبوة, صنعاء, اليمن]
# 501                                      None
#
# [502 rows x 12 columns]

# %%
tweet_df.to_csv("Sent_analysisfinal2223.csv", encoding="utf-32")
